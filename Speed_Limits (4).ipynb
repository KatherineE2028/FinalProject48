# %%
import pandas as pd
speed = pd.read_csv("Speed.tsv", sep="\t")
speed.head()
# Out:
#    _id          id  device_id    record_oid count_start_date count_end_date  \
# 0    1  1011743669         85  1.445865e+09       2019-04-18     2019-04-26
# 1    2  1026101993        140  1.121444e+09       2019-01-24            NaN
# 2    3  1032382575         11  1.539893e+09       2018-08-28     2018-09-04
# 3    4   103627606          9  7.341951e+08       2018-07-17     2018-08-01
# 4    5  1039546167        144           NaN              NaN            NaN
#
#    average_daily_car_traffic  average_daily_bike_traffic counter_number  \
# 0                     4949.0                         NaN              6
# 1                        NaN                         NaN            NaN
# 2                        NaN                         NaN            NaN
# 3                     2741.0                         NaN            NaN
# 4                        NaN                         NaN            NaN
#
#          counter_type  ...  longitude   latitude           neighborhood  \
# ...

# %% [markdown]
# ## Introduction ##
# For my program, I decided to rank the neighborhoods based on their speed limit keeping in mind that a slower speed limit would lead to fewer car accidents and thus a safer neighborhood. I started by importing my data set and using the ".groupby( )" function to organize it by neighborhood and ".mean( )" for the average speed limit and then organizing them from least to worst while putting the areas without a speed limit put at the bottom with the assumption that they would be more likely to cause accidents.

# %%
speed['speed_limit'] = pd.to_numeric(speed['speed_limit'], errors='coerce')

#Organzie dataset by neighborhood and display its average speed limit
mean_speed = speed.groupby('neighborhood')['speed_limit'].mean()

#Sort the neighborhoods from those with the lowest speed limits to those with the highest
sorted_mean_speed = mean_speed.sort_values()

#Create a rank collumn to give each neighborhood a quantifiable rank value
sorted_mean_speed = sorted_mean_speed.sort_values().reset_index()
sorted_mean_speed.index = sorted_mean_speed.index + 1
sorted_mean_speed.index.name = '#'

#Displays ordered mea
print((sorted_mean_speed))
# Out:
#                  neighborhood  speed_limit
# 0              Homewood South    21.666667
# 1                   Hazelwood    21.666667
# 2           South Side Slopes    24.375000
# 3                   Brookline    25.000000
# 4        California-Kirkbride    25.000000
# 5                     Carrick    25.000000
# 6   Central Business District    25.000000
# 7       Central Lawrenceville    25.000000
# 8           Central Northside    25.000000
# 9             Central Oakland    25.000000
# 10            Crafton Heights    25.000000
# 11              Lincoln Place    25.000000
# 12           Duquesne Heights    25.000000
# 13             East Allegheny    25.000000
# 14                 East Hills    25.000000
# 15                  Arlington    25.000000
# 16               East Liberty    25.000000
# 17                    Elliott    25.000000
# 18             Allegheny West    25.000000
# 19                   Fineview    25.000000
# 20                 Friendship    25.000000
# ...

# %% [markdown]
# ## Conclusion ##
# Ultimately the optimum neighborhoods based upon their speed limits ended up being Homewood South and Hazlewood with an average speed limit just above 21mph, I think this method of ranking makes the most sense as it puts the neighborhoods in a quantifiable order that removes any subjectivity or interperatation while following a proper reasoning that leads to a direct answer. My initial prediction for what would be the best neighborhood was Shady Side because of its approximity to shops and a nearby hostpital. Shadyside's average speed limit is 2nd to Homewood South and Hazlewood (along with several other neighborhoods) so while it ranks marginally less in safety, recreation might be lower however it cannot be quantified.
